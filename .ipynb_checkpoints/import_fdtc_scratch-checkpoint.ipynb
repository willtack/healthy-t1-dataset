# %%
import flywheel
import pandas as pd

# %%
fw = flywheel.Client()
project = fw.get('5e1cec8e3a9694005b6d12ab')
excel = pd.read_csv('sent_to_me/Controls-Prodromals_10-1.csv')

# %%
excel_sid_list = list(excel['INDDID'])
excel_ses_list = list(excel['MRIDateFormatted'])
print(len(excel_sid_list))
# convert sid list to string 
for i in range(len(excel_sid_list)):
    excel_sid_list[i] = str(excel_sid_list[i])
# Out:
# 459

# %%
excel_sid_list[0]

# %% [markdown]
# Create list of subjects and list of sessions in Flywheel project

# %%
fw_sid_list = []
for subject in project.subjects():
    #print(subject.label)
    fw_sid_list.append(subject.label)

fw_ses_list = []
for ses in project.sessions():
    #print(subject.label)
    fw_ses_list.append(ses.label)
    
print("done")

# %%
print(len(fw_sid_list))

# %%
collection = fw.get('5eb5081448fe1b1e5792a7a9')

# %%
# for ses in subject.sessions():
#     for acq in ses.acquisitions():
#         print(acq.label)
#         print(acq.id)

# %%
#collection.add_acquisitions(fw.get('5f2479eac888f404fa41c117'))

# %% [markdown]
# Method 1: loop through all acquisitions in FW of certain label, check if in FTDC project, check if in excel list

# %%
adding_ftdc = []
acquisitions = fw.acquisitions.find('label=t1_mpr_AX_MPRAGE')
for acquisition in acquisitions:
    subject = fw.get(acquisition.parents["subject"])
    if acquisition.parents["project"] =='5e1cec8e3a9694005b6d12ab' and subject.label in excel_sid_list:
        adding_ftdc.append(subject.label)
        #collection.add_acquisition(acquisition.id)
        
print(len(adding_ftdc))

# %%
#a.files[0]['classification']['Features']

# %% [markdown]
# Method 2: loop through sessions in FTDC, check if sub in list, loop through acqs

# %%
sessions_list = []
subs_list = []
acq_list = []
for ses in project.sessions():
    sub = fw.get(ses.parents['subject'])
    fw_ses_label = ses.label.split('-')[0]
    if sub.label in excel_sid_list:
        subs_list.append(sub.label)
        print('--')
        print(sub.label)
        row = excel.loc[excel['INDDID']==float(sub.label)]
        excel_ses_label = list(row['MRIDateFormatted'])[0]
        if fw_ses_label == str(excel_ses_label):
            sessions_list.append(ses.label)
            print(fw_ses_label)
            for acq in ses.acquisitions():
                print(acq.files[0]['classification'])
#                 has_mes = 'Measurement' in acq.files[0]['classification']
                if has_mes:
                    has_t1 = 'T1' in acq.files[0]['classification']['Measurement']
                else:
                    continue
#                 print('has measurements: ' + str(has_mes))
#                 print('has T1: ' + str(has_t1))
                if has_mes and has_t1:
                    print("HASSSSSSSSSSSSSSSS")
                    print(acq.label)
                    acq_list.append(acq.label)
print("Done!")
# Out:
# --
# 101841.02
# 20090106
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Non-Image'], 'Measurement': ['CSI']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Functional'], 'Features': ['2D', 'FAIR', 'FAIREST', 'FA', 'M0'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['2D', 'FAIR', 'FAIREST', 'FA'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['MPRAGE'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# t1_mpr_AX_MPRAGE
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['2D'], 'Measurement': ['T2*', 'BOLD']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Non-Image'], 'Measurement': ['CSI']}
# has measurements: True
# has T1: False
# --
# 101470.02
# 20080129
# {'Intent': ['Structural'], 'Features': ['MPRAGE'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# t1_mpr_AX_MPRAGE
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Functional'], 'Features': ['2D', 'FAIR', 'FAIREST', 'FA'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['2D', 'FAIR', 'FAIREST', 'FA', 'M0'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {'Intent': ['Non-Image'], 'Measurement': ['CSI']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Non-Image'], 'Measurement': ['CSI']}
# has measurements: True
# has T1: False
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# --
# 103703.04
# 20081209
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['2D'], 'Measurement': ['T2*', 'BOLD']}
# has measurements: True
# has T1: False
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['2D', 'FAIR', 'FAIREST', 'FA'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['2D', 'FAIR', 'FAIREST', 'FA', 'M0'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['MPRAGE'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# t1_mpr_AX_MPRAGE
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Non-Image'], 'Measurement': ['CSI']}
# has measurements: True
# has T1: False
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Non-Image'], 'Measurement': ['CSI']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# --
# 106053.13
# 20140220
# {'Intent': ['Structural'], 'Features': ['MPRAGE'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# t1_mpr_AX_MPRAGE
# {'Intent': ['Functional'], 'Measurement': ['T2*', 'BOLD']}
# has measurements: True
# has T1: False
# {}
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['2D', 'pCASL'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {}
# --
# 104613.05
# 20090601
# {'Intent': ['Non-Image'], 'Measurement': ['CSI']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Functional'], 'Features': ['2D', 'FAIR', 'FAIREST', 'FA'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['2D', 'FAIR', 'FAIREST', 'FA', 'M0'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Structural'], 'Features': ['MPRAGE'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# t1_mpr_AX_MPRAGE
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['2D'], 'Measurement': ['T2*', 'BOLD']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Non-Image'], 'Measurement': ['CSI']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# --
# 105769.07
# 20100630
# {'Intent': ['Functional'], 'Features': ['2D', 'pCASL'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['MPRAGE'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# t1_mpr_AX_MPRAGE
# {'Intent': ['Functional'], 'Features': ['Derived']}
# --
# 106053.06
# 20140307
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['MPRAGE'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# t1_mpr_AX_MPRAGE
# {}
# {'Intent': ['Functional'], 'Features': ['2D', 'pCASL'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Measurement': ['T2*', 'BOLD']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {}
# --
# 106053.09
# 20071022
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Non-Image'], 'Measurement': ['CSI']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Functional'], 'Features': ['2D', 'FAIR', 'FAIREST', 'FA'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Non-Image'], 'Measurement': ['CSI']}
# has measurements: True
# has T1: False
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['2D', 'FAIR', 'FAIREST', 'FA', 'M0'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['MPRAGE'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# t1_mpr_AX_MPRAGE
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# --
# 106053.06
# --
# 106053.06
# --
# 106053.14
# 20140728
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {}
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['MPRAGE'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# t1_mpr_AX_MPRAGE
# {'Intent': ['Functional'], 'Measurement': ['T2*', 'BOLD']}
# has measurements: True
# has T1: False
# {}
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['2D', 'pCASL'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# --
# 105769.06
# 20100630
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['2D', 'pCASL'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['MPRAGE'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# t1_mpr_AX_MPRAGE
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# --
# 106053.06
# --
# 105402.02
# 20130201
# {'Intent': ['Structural'], 'Features': ['MPRAGE'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# t1_mpr_AX_MPRAGE
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['2D', 'pCASL'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Measurement': ['T2*', 'BOLD']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['Derived']}
# --
# 108783.02
# 20050404
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Fieldmap'], 'Measurement': ['B0']}
# has measurements: True
# has T1: False
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['PD']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# t1_se_sag
# {'Intent': ['Functional'], 'Features': ['2D'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {'Intent': ['Fieldmap'], 'Measurement': ['B0']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['MPRAGE'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# t1_mpr_AX_MPRAGE
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# --
# 108783.11
# --
# 108061.02
# --
# 108783.07
# --
# 109050.02
# 20140310
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['2D', 'pCASL'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Measurement': ['T2*', 'BOLD']}
# has measurements: True
# has T1: False
# {}
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {}
# {'Intent': ['Structural'], 'Features': ['MPRAGE'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# t1_mpr_AX_MPRAGE
# --
# 107837.12
# 20150911
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# Sagittal MP-Rage
# {'Intent': ['Structural'], 'Features': ['MPRAGE'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# t1_mpr_AX_MPRAGE
# {'Intent': ['Structural'], 'Features': ['Derived', 'DTI', 'FA'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Non-Image'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['Derived', 'DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['Derived', 'DTI', 'TRACE'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['Derived', 'DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['2D', 'pCASL'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['FLAIR']}
# {'Intent': ['Structural'], 'Features': ['Derived', 'DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['Derived']}
# --
# 108636.04
# 20131101
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['MPRAGE'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# t1_mpr_AX_MPRAGE
# {}
# {}
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['2D', 'pCASL'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Measurement': ['T2*', 'BOLD']}
# has measurements: True
# has T1: False
# --
# 109476.04
# 20130603
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['MPRAGE'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# t1_mpr_AX_MPRAGE
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Measurement': ['T2*', 'BOLD']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['2D', 'pCASL'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# --
# 109476.06
# --
# 109476.06
# 20140819
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {}
# {'Intent': ['Structural'], 'Features': ['MPRAGE'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# t1_mpr_AX_MPRAGE
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Measurement': ['T2*', 'BOLD']}
# has measurements: True
# has T1: False
# {}
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['2D', 'pCASL'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# --
# 107837.15
# 20111103
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['2D', 'pCASL'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Measurement': ['T2*', 'BOLD']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Structural'], 'Features': ['MPRAGE'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# t1_mpr_AX_MPRAGE
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# --
# 108636.02
# 20131101
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Measurement': ['T2*', 'BOLD']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['2D', 'pCASL'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {}
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Structural'], 'Features': ['MPRAGE'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# t1_mpr_AX_MPRAGE
# {}
# --
# 108783.07
# --
# 109300.04
# 20121207
# {'Intent': ['Structural'], 'Features': ['MPRAGE'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# t1_mpr_AX_MPRAGE
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['2D', 'pCASL'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Measurement': ['T2*', 'BOLD']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['Derived']}
# --
# 108783.07
# --
# 108783.03
# --
# 108783.07
# 20180427
# {'Intent': ['Functional'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {'Measurement': ['Perfusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# Sagittal MP-Rage
# {'Features': ['PASL', '3D'], 'Measurement': ['Perfusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Non-Image'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['FLAIR']}
# {'Intent': ['Non-Image']}
# --
# 108783.06
# --
# 108783.11
# --
# 107837.12
# --
# 108061.02
# 20180409
# {'Features': ['PASL', '3D'], 'Measurement': ['Perfusion']}
# has measurements: True
# has T1: False
# {'Measurement': ['Perfusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['FLAIR']}
# {'Intent': ['Structural'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_moco
# {'Intent': ['Non-Image'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_setter
# {'Intent': ['Structural'], 'Features': ['RMS'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_moco RMS
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_setter
# {'Intent': ['Structural'], 'Features': ['RMS'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_moco_ND RMS
# {'Intent': ['Structural'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_moco_ND
# {'Intent': ['Structural'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# Sagittal MP-Rage
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_setter
# {'Intent': ['Functional'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_passive
# {'Intent': ['Structural'], 'Features': ['RMS'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_passive_ND RMS
# {'Intent': ['Non-Image']}
# {'Intent': ['Structural'], 'Features': ['RMS'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_passive RMS
# {'Intent': ['Structural'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_passive_ND
# --
# 108783.03
# --
# 108783.11
# 20090209
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['MPRAGE'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# t1_mpr_AX_MPRAGE
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['2D'], 'Measurement': ['T2*', 'BOLD']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['2D', 'FAIR', 'FAIREST', 'FA', 'M0'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['2D', 'FAIR', 'FAIREST', 'FA'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Non-Image'], 'Measurement': ['CSI']}
# has measurements: True
# has T1: False
# {'Intent': ['Non-Image'], 'Measurement': ['CSI']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['Derived']}
# --
# 109476.04
# --
# 108783.03
# 20120116
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Measurement': ['T2*', 'BOLD']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['MPRAGE'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# t1_mpr_AX_MPRAGE
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['2D', 'pCASL'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# --
# 108783.06
# 20180427
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['RMS'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_passive_ND RMS
# {'Intent': ['Structural'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_passive
# {'Measurement': ['Perfusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_setter
# {'Intent': ['Structural'], 'Features': ['RMS'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_passive RMS
# {'Intent': ['Structural'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_moco
# {'Features': ['PASL', '3D'], 'Measurement': ['Perfusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# Sagittal MP-Rage
# {'Intent': ['Structural'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_setter
# {'Intent': ['Structural'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_moco_ND
# {'Intent': ['Non-Image'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['FLAIR']}
# {'Intent': ['Structural'], 'Features': ['RMS'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_moco_ND RMS
# {'Intent': ['Non-Image']}
# {'Intent': ['Structural'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_setter
# {'Intent': ['Structural'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_passive_ND
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['RMS'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_moco RMS
# --
# 109476.04
# --
# 109050.03
# 20140314
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {}
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['MPRAGE'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# t1_mpr_AX_MPRAGE
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['2D', 'pCASL'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Measurement': ['T2*', 'BOLD']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {}
# --
# 108783.06
# --
# 108783.03
# --
# 108783.06
# --
# 110445.05
# 20141017
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# --
# 110445.03
# 20090219
# {'Intent': ['Functional'], 'Features': ['2D', 'FAIR', 'FAIREST', 'FA', 'M0'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Structural'], 'Features': ['MPRAGE'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# t1_mpr_AX_MPRAGE
# {'Intent': ['Functional'], 'Features': ['2D'], 'Measurement': ['T2*', 'BOLD']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['2D', 'FAIR', 'FAIREST', 'FA'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Non-Image'], 'Measurement': ['CSI']}
# has measurements: True
# has T1: False
# {'Intent': ['Non-Image'], 'Measurement': ['CSI']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# --
# 110445.02
# 20141010
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {}
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Measurement': ['T2*', 'BOLD']}
# has measurements: True
# has T1: False
# {}
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['2D', 'pCASL'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['MPRAGE'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# t1_mpr_AX_MPRAGE
# --
# 110445.02
# --
# 110445.05
# --
# 113113.05
# 20071119
# {'Intent': ['Non-Image'], 'Measurement': ['CSI']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['2D', 'FAIR', 'FAIREST', 'FA'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['2D', 'FAIR', 'FAIREST', 'FA', 'M0'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {'Intent': ['Non-Image'], 'Measurement': ['CSI']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Structural'], 'Features': ['MPRAGE'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# t1_mpr_AX_MPRAGE
# --
# 112976.07
# 20170914
# {'Intent': ['Structural'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_setter
# {'Intent': ['Structural'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_passive
# {'Intent': ['Functional'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_setter
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_passive_ND
# {'Intent': ['Non-Image']}
# {'Intent': ['Structural'], 'Features': ['RMS'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_passive RMS
# {'Intent': ['Structural'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_moco_ND
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['RMS'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_moco_ND RMS
# {'Intent': ['Structural'], 'Features': ['RMS'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_passive_ND RMS
# {'Measurement': ['Perfusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_moco
# {'Intent': ['Non-Image'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_setter
# {'Features': ['PASL', '3D'], 'Measurement': ['Perfusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# Sagittal MP-Rage
# {'Intent': ['Structural'], 'Features': ['RMS'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_moco RMS
# {'Intent': ['Structural'], 'Features': ['FLAIR']}
# --
# 111682.03
# 20140221
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['MPRAGE'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# t1_mpr_AX_MPRAGE
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {}
# {}
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Measurement': ['T2*', 'BOLD']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['2D', 'pCASL'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['Derived']}
# --
# 111682.05
# 20140418
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['MPRAGE'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# t1_mpr_AX_MPRAGE
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {}
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {}
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Measurement': ['T2*', 'BOLD']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['2D', 'pCASL'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# --
# 112976.06
# --
# 112976.07
# --
# 112976.06
# 20190517
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Features': ['PASL', '3D'], 'Measurement': ['Perfusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Non-Image'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Features': ['Spiral']}
# {'Intent': ['Structural'], 'Features': ['FLAIR']}
# {'Intent': ['Structural'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# Sagittal MP-Rage
# {'Intent': ['Structural'], 'Features': ['RMS'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_passive_ND RMS
# {'Intent': ['Functional'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['2D'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Measurement': ['Perfusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_setter
# {'Features': ['M0', 'Spiral']}
# {'Intent': ['Non-Image']}
# {'Intent': ['Structural'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_passive_ND
# {'Intent': ['Structural'], 'Features': ['RMS'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_passive RMS
# {'Intent': ['Structural'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_passive
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Features': ['Spiral'], 'Measurement': ['Perfusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['2D'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_setter
# --
# 111682.04
# 20140228
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {}
# {'Intent': ['Functional'], 'Features': ['2D', 'pCASL'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Measurement': ['T2*', 'BOLD']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {}
# {'Intent': ['Structural'], 'Features': ['MPRAGE'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# t1_mpr_AX_MPRAGE
# --
# 114854.02
# 20100628
# {'Intent': ['Functional'], 'Features': ['2D', 'pCASL'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['MPRAGE'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# t1_mpr_AX_MPRAGE
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# --
# 118913.04
# 20140624
# {'Intent': ['Functional'], 'Features': ['2D', 'pCASL'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {}
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {}
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['MPRAGE'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# t1_mpr_AX_MPRAGE
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Measurement': ['T2*', 'BOLD']}
# has measurements: True
# has T1: False
# --
# 118913.05
# 20140626
# {'Intent': ['Functional'], 'Measurement': ['T2*', 'BOLD']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['2D', 'pCASL'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['MPRAGE'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# t1_mpr_AX_MPRAGE
# {}
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {}
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['Derived']}
# --
# 119530.02
# --
# 118913.02
# 20181206
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Features': ['Spiral']}
# {'Intent': ['Structural'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# Sagittal MP-Rage
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['RMS'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_passive RMS
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['RMS'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_passive_ND RMS
# {'Intent': ['Structural'], 'Features': ['2D'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Measurement': ['Perfusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['FLAIR']}
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_setter
# {'Features': ['M0', 'Spiral']}
# {'Intent': ['Structural'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_passive_ND
# {'Intent': ['Structural'], 'Features': ['2D'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Non-Image'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Non-Image']}
# {'Features': ['PASL', '3D'], 'Measurement': ['Perfusion']}
# has measurements: True
# has T1: False
# {'Features': ['Spiral'], 'Measurement': ['Perfusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_setter
# {'Intent': ['Structural'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_setter
# {'Intent': ['Structural'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_passive
# --
# 118913.03
# 20140624
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['MPRAGE'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# t1_mpr_AX_MPRAGE
# {}
# {}
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Measurement': ['T2*', 'BOLD']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['2D', 'pCASL'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# --
# 120119.02
# 20170814
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['FLAIR']}
# {'Intent': ['Non-Image']}
# {'Intent': ['Functional'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# Sagittal MP-Rage
# {'Intent': ['Non-Image'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Features': ['PASL', '3D'], 'Measurement': ['Perfusion']}
# has measurements: True
# has T1: False
# {'Measurement': ['Perfusion']}
# has measurements: True
# has T1: False
# --
# 119530.03
# 20150522
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Measurement': ['T2*', 'BOLD']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['MPRAGE'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# t1_mpr_AX_MPRAGE
# {}
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['2D', 'pCASL'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {}
# --
# 120119.02
# --
# 119530.02
# --
# 120119.03
# 20150604
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['2D', 'pCASL'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {}
# {}
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Measurement': ['T2*', 'BOLD']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['MPRAGE'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# t1_mpr_AX_MPRAGE
# --
# 118913.06
# 20150723
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Features': ['Derived']}
# {}
# {}
# {'Intent': ['Functional'], 'Features': ['2D', 'pCASL'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {'Intent': ['Functional'], 'Measurement': ['T2*', 'BOLD']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['MPRAGE'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# t1_mpr_AX_MPRAGE
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# --
# 119530.02
# 20180627
# {'Intent': ['Structural'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# Sagittal MP-Rage
# {'Intent': ['Structural'], 'Features': ['FLAIR']}
# {'Intent': ['Localizer'], 'Measurement': ['T2']}
# has measurements: True
# has T1: False
# {'Intent': ['Non-Image'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_setter
# {'Intent': ['Structural'], 'Features': ['DTI'], 'Measurement': ['Diffusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['RMS'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_moco_ND RMS
# {'Intent': ['Structural'], 'Features': ['RMS'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_passive RMS
# {'Intent': ['Structural'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_setter
# {'Intent': ['Structural'], 'Features': ['RMS'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_moco RMS
# {'Intent': ['Functional'], 'Measurement': ['T2*']}
# has measurements: True
# has T1: False
# {'Intent': ['Non-Image']}
# {'Intent': ['Structural'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_moco
# {'Measurement': ['Perfusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_setter
# {'Features': ['PASL', '3D'], 'Measurement': ['Perfusion']}
# has measurements: True
# has T1: False
# {'Intent': ['Structural'], 'Features': ['RMS'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_passive_ND RMS
# {'Intent': ['Structural'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_moco_ND
# {'Intent': ['Structural'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_passive_ND
# {'Intent': ['Structural'], 'Measurement': ['T1']}
# has measurements: True
# has T1: True
# HASSSSSSSSSSSSSSSS
# ABCD_T1w_MPR_vNav_passive
# Done!

# %%
print(len(subs_list))
print(len(sessions_list))
print(len(acq_list))
# Out:
# 103
# 103
# 103

# %%
session = fw.get('5e28c0f2048f7100760634cb')
for a in session.acquisitions():
    print('{}: {}'.format(a.label, a.id))

# %%
acquisition = fw.get('5e28c107048f71005705faff')
acquisition.files[0]['classification']
has_mes = 'Measurement' in acquisition.files[0]['classification']
has_t1 = 'T1' in acquisition.files[0]['classification']['Measurement']
has_t1
# Out:
# True

# %%
acq.files[0]['classification']

# %%
"Features" in acq.files[0]['classification']

# %%
row = excel.loc[excel['INDDID']==101841.02]
excel_ses_label = list(row['MRIDateFormatted'])[0]
print(type(fw_ses_label))

# %%
print(len(subs_list))

# %%
row = excel.loc[excel['INDDID']==100267]
list(row['MRIDateFormatted'])[0]
